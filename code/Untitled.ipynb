# %%
# Import pandas, numpy, and matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# seaborn is a data visualization library built on matplotlib
import seaborn as sns
# set the plotting style
sns.set_style("whitegrid")

# Model preprocessing
from sklearn.preprocessing import StandardScaler

# Modeling
import statsmodels.formula.api as smf
import statsmodels.api as sm

# Model metrics and analysis
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from statsmodels.stats.anova import anova_lm

# %%
ccd_data = pd.read_csv(
    'https://raw.githubusercontent.com/brisamh/education/refs/heads/main/data/CCD_elsi_table_generator_data.csv',
    encoding='utf-8-sig',  # handles special characters and BOM
    dtype={'School ID (12-digit) - NCES Assigned [Public School] Latest available year': str,'School ID (7-digit) – NCES Assigned [Public School] 2016-17':str}
)

# %%
ccd_data.head()
# Out:
#                                     School Name  \
# 0               1 LT CHARLES W. WHITCOMB SCHOOL
# 1  100 ACADEMY OF ENGINEERING AND TECHNOLOGY ES
# 2  100 ACADEMY OF ENGINEERING AND TECHNOLOGY MS
# 3                            10TH STREET SCHOOL
# 4                     112 ALC INDEPENDENT STUDY
#
#   State Name [Public School] Latest available year  \
# 0                                    Massachusetts
# 1                                           Nevada
# 2                                           Nevada
# 3                                       Washington
# 4                                        Minnesota
#
#   Pupil/Teacher Ratio [Public School] 2016-17  \
# 0                                       11.22
# 1                                       21.28
# 2                                       39.33
# 3                                       24.79
# 4                                         NaN
#
#   Full-Time Equivalent (FTE) Teachers [Public School] 2016-17  \
# ...

# %%
ccd_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99860 entries, 0 to 99859
# Data columns (total 15 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   School Name                                                                 99857 non-null  object
#  1   State Name [Public School] Latest available year                            99853 non-null  object
#  2   Pupil/Teacher Ratio [Public School] 2016-17                                 94762 non-null  object
#  3   Full-Time Equivalent (FTE) Teachers [Public School] 2016-17                 98342 non-null  object
#  4   Grade 11 Students - male [Public School] 2016-17                            32794 non-null  object
#  5   Magnet School [Public School] 2016-17                                       87605 non-null  object
# ...

# %%
ccd_data['School ID (12-digit) - NCES Assigned [Public School] Latest available year'].iloc[0]
# Out:
# '2.50732E+11'
